# %% [markdown]
# ### 1. Load Datasets
# Loading test, train and validation sets into pandas dataframe

# %%
import pandas as pd

df_train = pd.read_json('data/raw/train.json', lines=True)
df_test = pd.read_json('data/raw/test.json', lines=True)
df_validation = pd.read_json('data/raw/validation.json', lines=True)

# %% [markdown]
# ### 2. Exploratory Data Analysis (Sayeed, Jui)
# #### Analyzing training dataset

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   quality_checked  1112 non-null   object
#  1   text             1112 non-null   object
#  2   task             1112 non-null   object
#  3   meta             1112 non-null   object
#  4   doc_id           1112 non-null   object
#  5   dataset_type     1112 non-null   object
#  6   annotator_id     1112 non-null   object
#  7   entity_mentions  1112 non-null   object
# dtypes: object(8)
# memory usage: 69.6+ KB

# %% [markdown]
# Observed no null values

# %%
df_train.head()
# Out:
#   quality_checked                                               text  \
# 0              []  PROCEDURE\n\nThe case originated in an applica...
# 1              []  PROCEDURE\n\nThe case originated in an applica...
# 2              []  PROCEDURE\n\nThe case originated in an applica...
# 3              []  PROCEDURE\n\nThe case originated in an applica...
# 4              []  PROCEDURE\n\nThe case originated in an applica...
#
#                                                 task  \
# 0  Task: Annotate the document to anonymise the f...
# 1  Task: Annotate the document to anonymise the f...
# 2  Task: Annotate the document to anonymise the f...
# 3  Task: Annotate the document to anonymise the f...
# 4  Task: Annotate the document to anonymise the f...
#
#                                                 meta     doc_id dataset_type  \
# 0  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194        train
# 1  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194        train
# 2  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194        train
# 3  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194        train
# 4  {'applicant': 'D. Stępniak', 'articles': [91, ...  001-84741        train
#
#   annotator_id                                    entity_mentions
# 0   annotator1  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 1   annotator2  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 2   annotator8  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 3  annotator11  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 4   annotator1  [{'confidential_status': 'NOT_CONFIDENTIAL', '...

# %% [markdown]
# Observation: We do not need dataset_type because the test, train and validation files are already separate. We also do not need the columns quality_checked, annotator_id.
#
# Dropping unrequired columns.

# %%
df_train.drop(columns=['quality_checked', 'dataset_type', 'annotator_id'])
# Out:
#                                                    text  \
# 0     PROCEDURE\n\nThe case originated in an applica...
# 1     PROCEDURE\n\nThe case originated in an applica...
# 2     PROCEDURE\n\nThe case originated in an applica...
# 3     PROCEDURE\n\nThe case originated in an applica...
# 4     PROCEDURE\n\nThe case originated in an applica...
# ...                                                 ...
# 1107  PROCEDURE\n\nThe case originated in an applica...
# 1108  PROCEDURE\n\nThe case originated in an applica...
# 1109  PROCEDURE\n\nThe case was referred to the Cour...
# 1110  PROCEDURE\n\nThe case originated in an applica...
# 1111  PROCEDURE\n\nThe case originated in an applica...
#
#                                                    task  \
# 0     Task: Annotate the document to anonymise the f...
# 1     Task: Annotate the document to anonymise the f...
# 2     Task: Annotate the document to anonymise the f...
# 3     Task: Annotate the document to anonymise the f...
# 4     Task: Annotate the document to anonymise the f...
# ...                                                 ...
# 1107  Task: Annotate the document to anonymise the f...
# 1108  Task: Annotate the document to anonymise the f...
# 1109  Task: Annotate the document to anonymise the f...
# 1110  Task: Annotate the document to anonymise the f...
# 1111  Task: Annotate the document to anonymise the f...
#
#                                                    meta      doc_id  \
# 0     {'applicant': 'Henrik Hasslund', 'articles': [...   001-90194
# 1     {'applicant': 'Henrik Hasslund', 'articles': [...   001-90194
# 2     {'applicant': 'Henrik Hasslund', 'articles': [...   001-90194
# 3     {'applicant': 'Henrik Hasslund', 'articles': [...   001-90194
# 4     {'applicant': 'D. Stępniak', 'articles': [91, ...   001-84741
# ...                                                 ...         ...
# 1107  {'applicant': 'Helmut Ludescher', 'articles': ...   001-60002
# 1108  {'applicant': 'J. Peter', 'articles': [91, 34,...  001-146353
# 1109  {'applicant': 'Christopher Ian Scott', 'articl...   001-58010
# 1110  {'applicant': 'Henryk Kreuz', 'articles': [91,...   001-61921
# 1111  {'applicant': 'Yiannis Kyriakou', 'articles': ...   001-90969
#
#                                         entity_mentions
# 0     [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 1     [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 2     [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 3     [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 4     [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# ...                                                 ...
# 1107  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 1108  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 1109  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 1110  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
# 1111  [{'confidential_status': 'NOT_CONFIDENTIAL', '...
#
# [1112 rows x 5 columns]

# %% [markdown]
# Analyzing task column

# %%
df_train['task'].unique()
# Out:
# array(['Task: Annotate the document to anonymise the following person: Henrik Hasslund',
#        'Task: Annotate the document to anonymise the following person: D. Stępniak',
#        'Task: Annotate the document to anonymise the following person: Nusret Amutgan',
#        ...,
#        'Task: Annotate the document to anonymise the following person: J. Peter',
#        'Task: Annotate the document to anonymise the following person: Christopher Ian Scott',
#        'Task: Annotate the document to anonymise the following person: Yiannis Kyriakou'],
#       dtype=object)

# %% [markdown]
# Observation: we don't need the task column
#
# Finding out how many unique values are there in text column and doc_id column. Making sure they match.

# %%
len(df_train['text'].unique())
# Out:
# 1014

# %%
len(df_train['doc_id'].unique())
# Out:
# 1014

# %% [markdown]
# Observation: We have 1014 unique values for documents but the dataset has 1112 entries. So there might be duplicates.

# %%
df_train['meta'][0]
# Out:
# {'applicant': 'Henrik Hasslund',
#  'articles': [91, 34, 54, 34, 93],
#  'countries': 'DNK',
#  'legal_branch': 'CHAMBER',
#  'year': 2008}

# %% [markdown]
# Observation: We may be able to reserve this column for later evaluation. Might be helpful to find out if our model struggles with region specific names, or has a bias, etc.

# %%
df_train_meta = df_train[['text', 'meta', 'doc_id']].copy()
df_train_meta.head()
# Out:
#                                                 text  \
# 0  PROCEDURE\n\nThe case originated in an applica...
# 1  PROCEDURE\n\nThe case originated in an applica...
# 2  PROCEDURE\n\nThe case originated in an applica...
# 3  PROCEDURE\n\nThe case originated in an applica...
# 4  PROCEDURE\n\nThe case originated in an applica...
#
#                                                 meta     doc_id
# 0  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194
# 1  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194
# 2  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194
# 3  {'applicant': 'Henrik Hasslund', 'articles': [...  001-90194
# 4  {'applicant': 'D. Stępniak', 'articles': [91, ...  001-84741

# %%
df_train_meta.to_csv('data/metadata/train_meta.csv')

# %%
df_test_meta = df_test[['text', 'meta', 'doc_id']].copy()
df_test_meta.to_csv('data/metadata/test_meta.csv')

df_validation_meta = df_validation[['text', 'meta', 'doc_id']].copy()
df_validation_meta.to_csv('data/metadata/validation_meta.csv')

# %% [markdown]
# Exploring entity mentions column

# %%
df_train['entity_mentions'][1]
# Out:
# [{'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 62,
#   'entity_id': '001-90194_a2_e1',
#   'entity_mention_id': '001-90194_a2_em1',
#   'entity_type': 'CODE',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '36244/06',
#   'start_offset': 54},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'correct',
#   'end_offset': 94,
#   'entity_id': '001-90194_a2_e2',
#   'entity_mention_id': '001-90194_a2_em2',
#   'entity_type': 'ORG',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Kingdom of Denmark',
#   'start_offset': 76},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 242,
#   'entity_id': '001-90194_a2_e3',
#   'entity_mention_id': '001-90194_a2_em3',
#   'entity_type': 'DEM',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Danish',
#   'start_offset': 236},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 271,
#   'entity_id': '001-90194_a2_e4',
#   'entity_mention_id': '001-90194_a2_em4',
#   'entity_type': 'PERSON',
#   'identifier_type': 'DIRECT',
#   'related_mentions': None,
#   'span_text': 'Mr Henrik Hasslund',
#   'start_offset': 253},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 308,
#   'entity_id': '001-90194_a2_e5',
#   'entity_mention_id': '001-90194_a2_em5',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '31 August 2006',
#   'start_offset': 294},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 357,
#   'entity_id': '001-90194_a2_e6',
#   'entity_mention_id': '001-90194_a2_em6',
#   'entity_type': 'PERSON',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Mr Tyge Trier',
#   'start_offset': 344},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 392,
#   'entity_id': '001-90194_a2_e7',
#   'entity_mention_id': '001-90194_a2_em7',
#   'entity_type': 'LOC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Copenhagen',
#   'start_offset': 382},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 415,
#   'entity_id': '001-90194_a2_e8',
#   'entity_mention_id': '001-90194_a2_em8',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Danish Government',
#   'start_offset': 398},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 493,
#   'entity_id': '001-90194_a2_e9',
#   'entity_mention_id': '001-90194_a2_em9',
#   'entity_type': 'PERSON',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Ms Nina Holst-Christensen',
#   'start_offset': 468},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 833,
#   'entity_id': '001-90194_a2_e10',
#   'entity_mention_id': '001-90194_a2_em10',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '1973',
#   'start_offset': 829},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 876,
#   'entity_id': '001-90194_a2_e11',
#   'entity_mention_id': '001-90194_a2_em11',
#   'entity_type': 'LOC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Les Salles Sur Verdon, France',
#   'start_offset': 847},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 908,
#   'entity_id': '001-90194_a2_e12',
#   'entity_mention_id': '001-90194_a2_em12',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'beginning of the 1990s',
#   'start_offset': 886},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 1010,
#   'entity_id': '001-90194_a2_e13',
#   'entity_mention_id': '001-90194_a2_em13',
#   'entity_type': 'LOC',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Denmark',
#   'start_offset': 1003},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 1606,
#   'entity_id': '001-90194_a2_e14',
#   'entity_mention_id': '001-90194_a2_em14',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'one thousand six hundred',
#   'start_offset': 1582},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 1680,
#   'entity_id': '001-90194_a2_e15',
#   'entity_mention_id': '001-90194_a2_em15',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'two billion Danish kroner (DKK)',
#   'start_offset': 1649},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 1728,
#   'entity_id': '001-90194_a2_e16',
#   'entity_mention_id': '001-90194_a2_em16',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'late 1980s',
#   'start_offset': 1718},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 1739,
#   'entity_id': '001-90194_a2_e17',
#   'entity_mention_id': '001-90194_a2_em17',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '1994',
#   'start_offset': 1735},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 1864,
#   'entity_id': '001-90194_a2_e18',
#   'entity_mention_id': '001-90194_a2_em18',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'summer of 1993',
#   'start_offset': 1850},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 1874,
#   'entity_id': '001-90194_a2_e17',
#   'entity_mention_id': '001-90194_a2_em19',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '1994',
#   'start_offset': 1870},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2064,
#   'entity_id': '001-90194_a2_e19',
#   'entity_mention_id': '001-90194_a2_em20',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '9 June 1994',
#   'start_offset': 2053},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2166,
#   'entity_id': '001-90194_a2_e20',
#   'entity_mention_id': '001-90194_a2_em21',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '14 June 1994',
#   'start_offset': 2154},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2327,
#   'entity_id': '001-90194_a2_e21',
#   'entity_mention_id': '001-90194_a2_em22',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'November 1994',
#   'start_offset': 2314},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 2345,
#   'entity_id': '001-90194_a2_e22',
#   'entity_mention_id': '001-90194_a2_em23',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'September 1995',
#   'start_offset': 2331},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 2350,
#   'entity_id': '001-90194_a2_e23',
#   'entity_mention_id': '001-90194_a2_em24',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'six',
#   'start_offset': 2347},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 2391,
#   'entity_id': '001-90194_a2_e24',
#   'entity_mention_id': '001-90194_a2_em25',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'two',
#   'start_offset': 2388},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 2403,
#   'entity_id': '001-90194_a2_e25',
#   'entity_mention_id': '001-90194_a2_em26',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'four',
#   'start_offset': 2399},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2488,
#   'entity_id': '001-90194_a2_e26',
#   'entity_mention_id': '001-90194_a2_em27',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '19 September 1995',
#   'start_offset': 2471},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2710,
#   'entity_id': '001-90194_a2_e27',
#   'entity_mention_id': '001-90194_a2_em28',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '22 December 1995',
#   'start_offset': 2694},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 2840,
#   'entity_id': '001-90194_a2_e28',
#   'entity_mention_id': '001-90194_a2_em29',
#   'entity_type': 'ORG',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Copenhagen City Court (Københavns Byret - hereafter “the City Court”)',
#   'start_offset': 2771},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2838,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em30',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 2828},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 2981,
#   'entity_id': '001-90194_a2_e30',
#   'entity_mention_id': '001-90194_a2_em31',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'beginning of 1996',
#   'start_offset': 2964},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3014,
#   'entity_id': '001-90194_a2_e31',
#   'entity_mention_id': '001-90194_a2_em32',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'January 1996 to June 1998',
#   'start_offset': 2989},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3079,
#   'entity_id': '001-90194_a2_e32',
#   'entity_mention_id': '001-90194_a2_em33',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'five',
#   'start_offset': 3075},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3135,
#   'entity_id': '001-90194_a2_e13',
#   'entity_mention_id': '001-90194_a2_em34',
#   'entity_type': 'LOC',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Denmark',
#   'start_offset': 3128},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3148,
#   'entity_id': '001-90194_a2_e33',
#   'entity_mention_id': '001-90194_a2_em35',
#   'entity_type': 'LOC',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Switzerland',
#   'start_offset': 3137},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3159,
#   'entity_id': '001-90194_a2_e34',
#   'entity_mention_id': '001-90194_a2_em36',
#   'entity_type': 'LOC',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Sweden',
#   'start_offset': 3153},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3191,
#   'entity_id': '001-90194_a2_e13',
#   'entity_mention_id': '001-90194_a2_em37',
#   'entity_type': 'LOC',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Denmark',
#   'start_offset': 3184},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3259,
#   'entity_id': '001-90194_a2_e35',
#   'entity_mention_id': '001-90194_a2_em38',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Interpol',
#   'start_offset': 3251},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3268,
#   'entity_id': '001-90194_a2_e36',
#   'entity_mention_id': '001-90194_a2_em39',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'fifteen',
#   'start_offset': 3261},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3377,
#   'entity_id': '001-90194_a2_e37',
#   'entity_mention_id': '001-90194_a2_em40',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '19 March 1997',
#   'start_offset': 3364},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3544,
#   'entity_id': '001-90194_a2_e38',
#   'entity_mention_id': '001-90194_a2_em41',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '25 June 1998',
#   'start_offset': 3532},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 3592,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em42',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 3582},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3635,
#   'entity_id': '001-90194_a2_e32',
#   'entity_mention_id': '001-90194_a2_em43',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'five',
#   'start_offset': 3631},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3664,
#   'entity_id': '001-90194_a2_e39',
#   'entity_mention_id': '001-90194_a2_em44',
#   'entity_type': 'MISC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'A, B, N, M and R',
#   'start_offset': 3648},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3768,
#   'entity_id': '001-90194_a2_e40',
#   'entity_mention_id': '001-90194_a2_em45',
#   'entity_type': 'MISC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'fifteen counts',
#   'start_offset': 3754},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3807,
#   'entity_id': '001-90194_a2_e41',
#   'entity_mention_id': '001-90194_a2_em46',
#   'entity_type': 'MISC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'fifty-nine committed',
#   'start_offset': 3787},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3839,
#   'entity_id': '001-90194_a2_e42',
#   'entity_mention_id': '001-90194_a2_em47',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'between March 1992 and May 1993',
#   'start_offset': 3808},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 3935,
#   'entity_id': '001-90194_a2_e43',
#   'entity_mention_id': '001-90194_a2_em48',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'DKK 9,890,000 (approximately 1,300,000 euros (EUR))',
#   'start_offset': 3884},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4028,
#   'entity_id': '001-90194_a2_e44',
#   'entity_mention_id': '001-90194_a2_em49',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'approximately EUR 19,000,000',
#   'start_offset': 4000},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4053,
#   'entity_id': '001-90194_a2_e45',
#   'entity_mention_id': '001-90194_a2_em50',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Between 14 August 1998',
#   'start_offset': 4031},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4071,
#   'entity_id': '001-90194_a2_e46',
#   'entity_mention_id': '001-90194_a2_em51',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '10 March 1999',
#   'start_offset': 4058},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 4080,
#   'entity_id': '001-90194_a2_e36',
#   'entity_mention_id': '001-90194_a2_em52',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'fifteen',
#   'start_offset': 4073},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4235,
#   'entity_id': '001-90194_a2_e47',
#   'entity_mention_id': '001-90194_a2_em53',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '15 March 1999',
#   'start_offset': 4222},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4259,
#   'entity_id': '001-90194_a2_e48',
#   'entity_mention_id': '001-90194_a2_em54',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'Between 15 March 1999',
#   'start_offset': 4238},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4279,
#   'entity_id': '001-90194_a2_e49',
#   'entity_mention_id': '001-90194_a2_em55',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '31 January 2001',
#   'start_offset': 4264},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 4295,
#   'entity_id': '001-90194_a2_e50',
#   'entity_mention_id': '001-90194_a2_em56',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '119',
#   'start_offset': 4292},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4339,
#   'entity_id': '001-90194_a2_e32',
#   'entity_mention_id': '001-90194_a2_em57',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'five',
#   'start_offset': 4335},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 4574,
#   'entity_id': '001-90194_a2_e51',
#   'entity_mention_id': '001-90194_a2_em58',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '1,330',
#   'start_offset': 4569},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4626,
#   'entity_id': '001-90194_a2_e52',
#   'entity_mention_id': '001-90194_a2_em59',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'ten days',
#   'start_offset': 4618},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4643,
#   'entity_id': '001-90194_a2_e53',
#   'entity_mention_id': '001-90194_a2_em60',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'November 2000',
#   'start_offset': 4630},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4660,
#   'entity_id': '001-90194_a2_e54',
#   'entity_mention_id': '001-90194_a2_em61',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'January 2001',
#   'start_offset': 4648},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4692,
#   'entity_id': '001-90194_a2_e55',
#   'entity_mention_id': '001-90194_a2_em62',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '6 April 2001',
#   'start_offset': 4680},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 4710,
#   'entity_id': '001-90194_a2_e56',
#   'entity_mention_id': '001-90194_a2_em63',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '220',
#   'start_offset': 4707},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4732,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em64',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 4722},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 4903,
#   'entity_id': '001-90194_a2_e57',
#   'entity_mention_id': '001-90194_a2_em65',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'two years',
#   'start_offset': 4894},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 4958,
#   'entity_id': '001-90194_a2_e58',
#   'entity_mention_id': '001-90194_a2_em66',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'DKK 2,200,000',
#   'start_offset': 4945},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 5219,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em67',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 5209},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 5380,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em68',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 5370},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 5505,
#   'entity_id': '001-90194_a2_e32',
#   'entity_mention_id': '001-90194_a2_em69',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'five',
#   'start_offset': 5501},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 5628,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em70',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 5618},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 5854,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em71',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 5844},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 5936,
#   'entity_id': '001-90194_a2_e32',
#   'entity_mention_id': '001-90194_a2_em72',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'five',
#   'start_offset': 5932},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6125,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em73',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 6115},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 6226,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em74',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 6216},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6364,
#   'entity_id': '001-90194_a2_e59',
#   'entity_mention_id': '001-90194_a2_em75',
#   'entity_type': 'MISC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '[M]',
#   'start_offset': 6361},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6393,
#   'entity_id': '001-90194_a2_e60',
#   'entity_mention_id': '001-90194_a2_em76',
#   'entity_type': 'MISC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '[the co-accused B and R]',
#   'start_offset': 6369},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6461,
#   'entity_id': '001-90194_a2_e61',
#   'entity_mention_id': '001-90194_a2_em77',
#   'entity_type': 'MISC',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '[the applicant, N and A]',
#   'start_offset': 6437},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 6454,
#   'entity_id': '001-90194_a2_e62',
#   'entity_mention_id': '001-90194_a2_em78',
#   'entity_type': 'ORG',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'N',
#   'start_offset': 6453},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 6559,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em79',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 6549},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 6707,
#   'entity_id': '001-90194_a2_e63',
#   'entity_mention_id': '001-90194_a2_em80',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '15 May 2001',
#   'start_offset': 6696},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 6734,
#   'entity_id': '001-90194_a2_e32',
#   'entity_mention_id': '001-90194_a2_em81',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'five',
#   'start_offset': 6730},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6848,
#   'entity_id': '001-90194_a2_e64',
#   'entity_mention_id': '001-90194_a2_em82',
#   'entity_type': 'ORG',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'High Court of Eastern Denmark (Østre Landsret - “the High Court”)',
#   'start_offset': 6783},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6846,
#   'entity_id': '001-90194_a2_e65',
#   'entity_mention_id': '001-90194_a2_em83',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'the High Court',
#   'start_offset': 6832},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 6874,
#   'entity_id': '001-90194_a2_e66',
#   'entity_mention_id': '001-90194_a2_em84',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'twelve',
#   'start_offset': 6868},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 6941,
#   'entity_id': '001-90194_a2_e67',
#   'entity_mention_id': '001-90194_a2_em85',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '13 September 2001',
#   'start_offset': 6924},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7037,
#   'entity_id': '001-90194_a2_e68',
#   'entity_mention_id': '001-90194_a2_em86',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '24 September 2002',
#   'start_offset': 7020},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7184,
#   'entity_id': '001-90194_a2_e69',
#   'entity_mention_id': '001-90194_a2_em87',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'autumn of 2002',
#   'start_offset': 7170},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7242,
#   'entity_id': '001-90194_a2_e68',
#   'entity_mention_id': '001-90194_a2_em88',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '24 September 2002',
#   'start_offset': 7225},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7283,
#   'entity_id': '001-90194_a2_e70',
#   'entity_mention_id': '001-90194_a2_em89',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '2003',
#   'start_offset': 7279},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7292,
#   'entity_id': '001-90194_a2_e71',
#   'entity_mention_id': '001-90194_a2_em90',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '2004',
#   'start_offset': 7288},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'correct',
#   'end_offset': 7313,
#   'entity_id': '001-90194_a2_e72',
#   'entity_mention_id': '001-90194_a2_em91',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'about 90',
#   'start_offset': 7305},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7357,
#   'entity_id': '001-90194_a2_e73',
#   'entity_mention_id': '001-90194_a2_em92',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'February',
#   'start_offset': 7349},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7372,
#   'entity_id': '001-90194_a2_e74',
#   'entity_mention_id': '001-90194_a2_em93',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'March 2004',
#   'start_offset': 7362},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7479,
#   'entity_id': '001-90194_a2_e75',
#   'entity_mention_id': '001-90194_a2_em94',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'High Court',
#   'start_offset': 7469},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 7554,
#   'entity_id': '001-90194_a2_e76',
#   'entity_mention_id': '001-90194_a2_em95',
#   'entity_type': 'QUANTITY',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '861',
#   'start_offset': 7551},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7606,
#   'entity_id': '001-90194_a2_e52',
#   'entity_mention_id': '001-90194_a2_em96',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'ten days',
#   'start_offset': 7598},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7620,
#   'entity_id': '001-90194_a2_e77',
#   'entity_mention_id': '001-90194_a2_em97',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'April, May',
#   'start_offset': 7610},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7635,
#   'entity_id': '001-90194_a2_e78',
#   'entity_mention_id': '001-90194_a2_em98',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'June 2004',
#   'start_offset': 7626},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7658,
#   'entity_id': '001-90194_a2_e79',
#   'entity_mention_id': '001-90194_a2_em99',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '28 September 2004',
#   'start_offset': 7641},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7673,
#   'entity_id': '001-90194_a2_e75',
#   'entity_mention_id': '001-90194_a2_em100',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'High Court',
#   'start_offset': 7663},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7695,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em101',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 7685},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7927,
#   'entity_id': '001-90194_a2_e26',
#   'entity_mention_id': '001-90194_a2_em102',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '19 September 1995',
#   'start_offset': 7910},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7968,
#   'entity_id': '001-90194_a2_e75',
#   'entity_mention_id': '001-90194_a2_em103',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'High Court',
#   'start_offset': 7958},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 7992,
#   'entity_id': '001-90194_a2_e29',
#   'entity_mention_id': '001-90194_a2_em104',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'City Court',
#   'start_offset': 7982},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8217,
#   'entity_id': '001-90194_a2_e67',
#   'entity_mention_id': '001-90194_a2_em105',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '13 September 2001',
#   'start_offset': 8200},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8293,
#   'entity_id': '001-90194_a2_e80',
#   'entity_mention_id': '001-90194_a2_em106',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '12 August 2002',
#   'start_offset': 8279},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8339,
#   'entity_id': '001-90194_a2_e81',
#   'entity_mention_id': '001-90194_a2_em107',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'autumn 2002',
#   'start_offset': 8328},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8365,
#   'entity_id': '001-90194_a2_e82',
#   'entity_mention_id': '001-90194_a2_em108',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'beginning of 2003',
#   'start_offset': 8348},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8601,
#   'entity_id': '001-90194_a2_e68',
#   'entity_mention_id': '001-90194_a2_em109',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '24 September 2002',
#   'start_offset': 8584},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8702,
#   'entity_id': '001-90194_a2_e83',
#   'entity_mention_id': '001-90194_a2_em110',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '7 to 12 October 2004',
#   'start_offset': 8682},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 8805,
#   'entity_id': '001-90194_a2_e84',
#   'entity_mention_id': '001-90194_a2_em111',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Appeal Board (Procesbevillingsnævnet)',
#   'start_offset': 8768},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 8853,
#   'entity_id': '001-90194_a2_e85',
#   'entity_mention_id': '001-90194_a2_em112',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Supreme Court',
#   'start_offset': 8840},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'insert',
#   'end_offset': 8866,
#   'entity_id': '001-90194_a2_e86',
#   'entity_mention_id': '001-90194_a2_em113',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Supreme Court (Højesteret)',
#   'start_offset': 8840},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9004,
#   'entity_id': '001-90194_a2_e87',
#   'entity_mention_id': '001-90194_a2_em114',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '17 December 2004',
#   'start_offset': 8988},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9021,
#   'entity_id': '001-90194_a2_e88',
#   'entity_mention_id': '001-90194_a2_em115',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': 'January 2005',
#   'start_offset': 9009},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9101,
#   'entity_id': '001-90194_a2_e89',
#   'entity_mention_id': '001-90194_a2_em116',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '29 March 2005',
#   'start_offset': 9088},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9201,
#   'entity_id': '001-90194_a2_e90',
#   'entity_mention_id': '001-90194_a2_em117',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '5 August 2005',
#   'start_offset': 9188},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9326,
#   'entity_id': '001-90194_a2_e91',
#   'entity_mention_id': '001-90194_a2_em118',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '9 August 2005',
#   'start_offset': 9313},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9547,
#   'entity_id': '001-90194_a2_e92',
#   'entity_mention_id': '001-90194_a2_em119',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '2 May 2006',
#   'start_offset': 9537},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9778,
#   'entity_id': '001-90194_a2_e93',
#   'entity_mention_id': '001-90194_a2_em120',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '2 and 13 June 2006',
#   'start_offset': 9760},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9844,
#   'entity_id': '001-90194_a2_e94',
#   'entity_mention_id': '001-90194_a2_em121',
#   'entity_type': 'DATETIME',
#   'identifier_type': 'QUASI',
#   'related_mentions': None,
#   'span_text': '21 June 2006',
#   'start_offset': 9832},
#  {'confidential_status': 'NOT_CONFIDENTIAL',
#   'edit_type': 'check',
#   'end_offset': 9905,
#   'entity_id': '001-90194_a2_e85',
#   'entity_mention_id': '001-90194_a2_em122',
#   'entity_type': 'ORG',
#   'identifier_type': 'NO_MASK',
#   'related_mentions': None,
#   'span_text': 'Supreme Court',
#   'start_offset': 9892}]

# %%
import json
df_train_exploded = df_train.explode('entity_mentions')
entities_flat = pd.json_normalize(df_train_exploded['entity_mentions'])
df_train_entities = pd.concat([df_train_exploded[['doc_id']].reset_index(drop=True), entities_flat.reset_index(drop=True)], axis=1)

df_train_entities.head()
# Out:
#       doc_id confidential_status edit_type  end_offset        entity_id  \
# 0  001-90194    NOT_CONFIDENTIAL     check          62  001-90194_a1_e1
# 1  001-90194    NOT_CONFIDENTIAL   correct          94  001-90194_a1_e2
# 2  001-90194    NOT_CONFIDENTIAL     check         242  001-90194_a1_e3
# 3  001-90194    NOT_CONFIDENTIAL     check         271  001-90194_a1_e4
# 4  001-90194    NOT_CONFIDENTIAL     check         308  001-90194_a1_e5
#
#   entity_mention_id entity_type identifier_type related_mentions  \
# 0  001-90194_a1_em1        CODE          DIRECT             None
# 1  001-90194_a1_em2         ORG         NO_MASK             None
# 2  001-90194_a1_em3         DEM         NO_MASK             None
# 3  001-90194_a1_em4      PERSON          DIRECT             None
# 4  001-90194_a1_em5    DATETIME           QUASI             None
#
#             span_text  start_offset
# 0            36244/06            54
# 1  Kingdom of Denmark            76
# 2              Danish           236
# 3  Mr Henrik Hasslund           253
# 4      31 August 2006           294

# %% [markdown]
# Observation: We have start_offset, end_offset and entity_type. We need to extract this data to create a token and tags for finetuning DistilliBERT model.

# %% [markdown]
# Checking the counts of entities for filtered set where identifier_type is not NO_MASK

# %%
print("Entity Type Counts:")
entity_type_stats = df_train_entities[df_train_entities['identifier_type'] != 'NO_MASK']['entity_type'].value_counts()
entity_type_stats.plot(kind='bar', title='Distribution of Entity Types')
# Out:
# Entity Type Counts:
# <Axes: title={'center': 'Distribution of Entity Types'}, xlabel='entity_type'>

# %% [markdown]
# Certain imbalance of data is seen here where datetime entities are much higher in count than quantity or code

# %%
# Check masking requirements
mask_stats = df_train_entities['identifier_type'].value_counts()
mask_stats.plot(kind='bar', title='Distribution of Masking Needs')
# Out:
# <Axes: title={'center': 'Distribution of Masking Needs'}, xlabel='identifier_type'>

# %%
entities_per_doc = df_train_entities.groupby('doc_id').size().sort_values(ascending=False)
entities_per_doc.plot(kind='hist', bins=30, title='Entities per Document Distribution', xlabel='Number of Entities', ylabel='Number of Documents')
# Out:
# <Axes: title={'center': 'Entities per Document Distribution'}, xlabel='Number of Entities', ylabel='Number of Documents'>

# %%
print(f"Average entities per document: {entities_per_doc.mean():.2f}")
# Out:
# Average entities per document: 93.72

# %% [markdown]
# ### 3. Data pre-processing (Jui)
# Converting offests to list

# %%
def convert_offsets_to_lists(row):
    text = row['text']
    entities = row['entity_mentions']

    # create character-level map
    char_tags = ["O"] * len(text)

    for ent in entities:
        # Filter 'NO_MASK' entities
        if ent.get('identifier_type') == 'NO_MASK':
            continue

        start, end = ent['start_offset'], ent['end_offset']
        label = ent['entity_type']

        # fill character-level map
        if start < len(text) and end <= len(text):
            char_tags[start] = f"B-{label}" # beginning of entity
            for i in range(start+1, end):
                char_tags[i] = f"I-{label}" # inside entity

    # convert character map to word - tag
    tokens = text.split()
    ner_tags = []

    cursor = 0
    for token in tokens:
        # advance cursor to the start of word (skipping spaces)
        while cursor < len(text) and text[cursor].isspace():
            cursor += 1

        # tag of the word is the tag of its first character
        if cursor < len(text):
            ner_tags.append(char_tags[cursor])
            cursor += len(token)
        else:
            ner_tags.append("O")

    return {"tokens": tokens, "ner_tags": ner_tags}

# %%
from datasets import Dataset

# converting Pandas to Hugging Face Dataset
hf_train = Dataset.from_pandas(df_train)
train_processed = hf_train.map(convert_offsets_to_lists)

# Quick Check:
print(train_processed[0]['tokens'])
print(train_processed[0]['ner_tags'])
# Out:
# Map:   0%|          | 0/1112 [00:00<?, ? examples/s]
# ['PROCEDURE', 'The', 'case', 'originated', 'in', 'an', 'application', '(no.', '36244/06)', 'against', 'the', 'Kingdom', 'of', 'Denmark', 'lodged', 'with', 'the', 'Court', 'under', 'Article', '34', 'of', 'the', 'Convention', 'for', 'the', 'Protection', 'of', 'Human', 'Rights', 'and', 'Fundamental', 'Freedoms', '(“the', 'Convention”)', 'by', 'a', 'Danish', 'national,', 'Mr', 'Henrik', 'Hasslund', '(“the', 'applicant”),', 'on', '31', 'August', '2006.', 'The', 'applicant', 'was', 'represented', 'by', 'Mr', 'Tyge', 'Trier,', 'a', 'lawyer', 'practising', 'in', 'Copenhagen.', 'The', 'Danish', 'Government', '(“the', 'Government”)', 'were', 'represented', 'by', 'their', 'Agent,', 'Ms', 'Nina', 'Holst-Christensen', 'of', 'the', 'Ministry', 'of', 'Justice.', 'On', '5', 'September', '2007', 'the', 'Acting', 'President', 'of', 'the', 'Fifth', 'Section', 'decided', 'to', 'give', 'notice', 'of', 'the', 'application', 'to', 'the', 'Government.', 'It', 'was', 'also', 'decided', 'to', 'rule', 'on', 'the', 'admissibility', 'and', 'merits', 'of', 'the', 'application', 'at', 'the', 'same', 'time', '(Article', '29', '§', '3).', 'THE', 'FACTS', 'THE', 'CIRCUMSTANCES', 'OF', 'THE', 'CASE', 'The', 'applicant', 'was', 'born', 'in', '1973', 'and', 'lives', 'in', 'Les', 'Salles', 'Sur', 'Verdon,', 'France.', 'At', 'the', 'beginning', 'of', 'the', '1990s', 'a', 'new', 'concept', 'called', '“tax', 'asset', 'stripping', 'cases”', '(selskabstømmersager)', 'came', 'into', 'existence', 'in', 'Denmark.', 'It', 'covered', 'a', 'criminal', 'activity', 'by', 'which', 'the', 'persons', 'involved', 'committed', 'aggravated', 'debtor', 'fraud', 'by', 'buying', 'up', 'and', 'selling', 'numerous', 'inactive,', 'solvent', 'private', 'limited', 'companies', 'within', 'a', 'short', 'period', 'and,', 'for', 'the', 'sake', 'of', 'their', 'own', 'profit,', '“stripping”', 'the', 'companies', 'of', 'assets,', 'including', 'deposits', 'earmarked', 'for', 'payment', 'of', 'corporation', 'tax.', 'The', 'persons', 'involved', 'were', 'usually', 'intricately', 'interconnected', 'and', 'collaborated', 'in', 'their', 'economic', 'criminal', 'activities,', 'which', 'concerned', 'very', 'large', 'amounts', 'of', 'money.', 'According', 'to', 'surveys', 'made', 'by', 'the', 'customs', 'and', 'tax', 'authorities,', 'approximately', 'one', 'thousand', 'six', 'hundred', 'companies', 'with', 'a', 'total', 'tax', 'debt', 'exceeding', 'two', 'billion', 'Danish', 'kroner', '(DKK)', 'were', 'stripped', 'in', 'the', 'period', 'from', 'the', 'late', '1980s', 'until', '1994.', 'Following', 'a', 'number', 'of', 'legislative', 'amendments,', 'the', 'trade', 'in', 'inactive,', 'solvent', 'companies', 'largely', 'ceased', 'in', 'the', 'summer', 'of', '1993.', 'In', '1994,', 'the', 'applicant', 'learnt', 'via', 'a', 'local', 'newspaper', 'that', 'he', 'was', 'the', 'subject', 'of', 'an', 'investigation,', 'as', 'was', 'a', 'private', 'limited', 'stockbrokers', 'company,', 'of', 'which', 'he', 'was', 'part', 'owner.', 'By', 'letter', 'of', '9', 'June', '1994', 'he', 'informed', 'the', 'police', 'that', 'he', 'was', 'available', 'for', 'an', 'interview,', 'if', 'required.', 'By', 'letter', 'of', '14', 'June', '1994', 'the', 'police', 'confirmed', 'that', 'they', 'were', 'in', 'the', 'process', 'of', 'investigation', 'and', 'informed', 'the', 'applicant', 'that', 'they', 'would', 'talk', 'to', 'him', 'at', 'a', 'later', 'stage.', 'From', 'November', '1994', 'to', 'September', '1995,', 'six', 'discovery', 'orders', 'were', 'issued', 'against', 'two', 'banks,', 'four', 'search', 'warrants', 'were', 'issued', 'and', 'numerous', 'interviews', 'were', 'held.', 'On', '19', 'September', '1995', 'the', 'applicant', 'was', 'arrested', 'and', 'charged,', 'inter', 'alia,', 'with', 'aggravated', 'debtor', 'fraud.', 'On', 'the', 'same', 'day', 'he', 'was', 'detained', 'in', 'solitary', 'confinement,', 'which', 'was', 'prolonged', 'at', 'regular', 'intervals', 'until', 'he', 'was', 'released', 'on', '22', 'December', '1 ...
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CODE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'O', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'O', 'B-QUANTITY', 'I-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'O', 'B-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'I-DATETIME', 'B-QUANTITY', 'I-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'O' ...

# %% [markdown]
# Create label mappings from train set to be used to pass when training the model, same mappings would be used during tokenization of test and validation sets as well

# %%
# extracting unique tags from training data
unique_tags = set(tag for row in train_processed for tag in row['ner_tags'])
label_list = sorted(list(unique_tags)) # e.g., ['B-LOC', 'B-PER', 'I-PER', 'O']

# createing maps
label2id = {label: i for i, label in enumerate(label_list)}
id2label = {i: label for i, label in enumerate(label_list)}

print(f"Number of labels: {len(label_list)}")
print(label2id)
# Out:
# Number of labels: 17
# {'B-CODE': 0, 'B-DATETIME': 1, 'B-DEM': 2, 'B-LOC': 3, 'B-MISC': 4, 'B-ORG': 5, 'B-PERSON': 6, 'B-QUANTITY': 7, 'I-CODE': 8, 'I-DATETIME': 9, 'I-DEM': 10, 'I-LOC': 11, 'I-MISC': 12, 'I-ORG': 13, 'I-PERSON': 14, 'I-QUANTITY': 15, 'O': 16}

# %% [markdown]
# Using AutoTokenizer to handle sub-words and align new tags. Defining tokenization function to be used various versions of BERT

# %%
def tokenize_and_align(examples, tokenizer):
  '''Takes the tokenizer object as input and operated on a row in huggingface dataset object'''
  # split words into sub-words
  tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

  labels = []
  for i, label in enumerate(examples["ner_tags"]):
      word_ids = tokenized_inputs.word_ids(batch_index=i) #supported only for fast tokenizers
      previous_word_idx = None
      label_ids = []
      for word_idx in word_ids:
          if word_idx is None:
              # special tokens like [CLS] get -100 (ignored)
              label_ids.append(-100)
          elif word_idx != previous_word_idx:
              # first piece of a word gets the real label ID
              label_ids.append(label2id[label[word_idx]]) #using map created from training set
          else:
              # subsequent pieces (e.g., "##lor") get -100 (ignored)
              label_ids.append(-100)
          previous_word_idx = word_idx
      labels.append(label_ids)

  tokenized_inputs["labels"] = labels
  return tokenized_inputs

# %% [markdown]
# Writing a script for processing test and validation sets

# %%
def preprocess_data(df, tokenizer):
  '''Takes a pandas dataframe and a tokenizer object and returns a tokenized huggingface dataset object ready to be passed into BERT for training
  '''
  # converting Pandas to Hugging Face Dataset
  hf = Dataset.from_pandas(df)
  processed = hf.map(convert_offsets_to_lists)
  #tokenize
  tokenized = processed.map(tokenize_and_align, batched=True, fn_kwargs={"tokenizer": tokenizer})

  return tokenized

# %% [markdown]
# Importing AutoTokenizer to use various BERT tokenizers

# %%
from transformers import AutoTokenizer

# %% [markdown]
# ## 4. Bi-LSTM (Jui)
#
# Using DistilBERT tokenizer to keep the comparison fair

# %%
tokenizer_distilbert = AutoTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
train_distilbert = preprocess_data(df_train ,tokenizer_distilbert)
# Out:
# Map:   0%|          | 0/1112 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1112 [00:00<?, ? examples/s]

# %%
test_distilbert = preprocess_data(df_test, tokenizer_distilbert)
validation_distilbert = preprocess_data(df_validation, tokenizer_distilbert)
# Out:
# Map:   0%|          | 0/555 [00:00<?, ? examples/s]
# Map:   0%|          | 0/555 [00:00<?, ? examples/s]
# Map:   0%|          | 0/541 [00:00<?, ? examples/s]
# Map:   0%|          | 0/541 [00:00<?, ? examples/s]

# %% [markdown]
# Importing pyTorch

# %%
import torch
import torch.nn as nn

# %%
#setup GPU availability
if torch.backends.mps.is_available():
    device = torch.device('mps') #mac m3 chip integrated gpu
    print(f"MPS device found: {device}")
elif torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"GPU device found: {device}")
else:
    device = torch.device('cpu')
    print(f"No GPU device found. Falling back to {device}")
# Out:
# No GPU device found. Falling back to cpu

# %% [markdown]
# Defining the Bi-LSTM model for NER

# %%
class bilstm_nre(nn.Module):
  def __init__(self, vocab_size, num_labels, embed_dim=128, hidden_dim=256, weight_tensor=None, dropout_rate=None):
      super().__init__()

      #setting up a custom embedding layer
      #seting padding index to 0 the embedding model from learning vectors for padding
      self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

      #bi-lstm layer
      self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)

      #dropout
      if dropout_rate is not None:
        self.dropout = nn.Dropout(dropout_rate)

      #output layer (2*hidden_dim for bi-lstm)
      self.classifier = nn.Linear(hidden_dim * 2, num_labels)

      #set loss function (ignore_index=-100 because we set masking to -100 in previous function)
      if weight_tensor is not None:
        self.loss_fct = nn.CrossEntropyLoss(ignore_index=-100, weight=weight_tensor)
      else:
        self.loss_fct = nn.CrossEntropyLoss(ignore_index=-100)

  #forward pass
  def forward(self, input_ids, labels=None):
      #embed
      embeds = self.embedding(input_ids)

      #lstm forward
      lstm_out, _ = self.lstm(embeds)

      logits = self.classifier(lstm_out)

      #loss calculation
      loss = None
      if labels is not None:
          # Flatten the tensors so we can check every token at once
          # logits shape: (batch * seq_len, num_labels)
          # labels shape: (batch * seq_len)
          loss = self.loss_fct(logits.view(-1, logits.shape[-1]), labels.view(-1))

      return loss, logits

# %% [markdown]
# batch pre-processing function to prepare dataloaders

# %%
def collate_fn(batch):
    # convert batch to tensors
    input_ids = [torch.tensor(item['input_ids']) for item in batch]
    labels = [torch.tensor(item['labels']) for item in batch]

    # padding inputs with 0(blank space), labels with -100
    input_ids = torch.nn.utils.rnn.pad_sequence(input_ids, batch_first=True, padding_value=0)
    labels = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True, padding_value=-100)

    return input_ids.to(device), labels.to(device)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_distilbert, batch_size=16, shuffle=True, collate_fn=collate_fn)

# %%
test_loader = DataLoader(test_distilbert, batch_size=16, shuffle=True, collate_fn=collate_fn)
validation_loader = DataLoader(validation_distilbert, batch_size=16, shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# Tracking model performance at every epoch

# %%
#using huggingface evaluate library for NER evaluation
# !pip install evaluate seqeval
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.3.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.12/dist-packages (from seqeval) (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (3.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=0e1e3450d0696db25a0b45316cfeb56a8207d20f1037a3df701b9c21c7692f87
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: seqeval, evaluate
# Successfully installed evaluate-0.4.6 seqeval-1.2.2

# %%
import matplotlib.pyplot as plt
import evaluate
import numpy as np

# %% [markdown]
# Function to evaluate after every epoch

# %%
seqeval = evaluate.load("seqeval")

def evaluate_epoch(model, dataloader, label_list):
    model.eval() # Set to evaluation mode

    all_preds = []
    all_labels = []
    total_val_loss = 0

    with torch.no_grad():
        for batch_ids, batch_labels in dataloader:
            batch_ids = batch_ids.to(device)
            batch_labels = batch_labels.to(device)

            # Forward pass
            loss, logits = model(batch_ids, batch_labels)

            # test loss
            total_val_loss += loss.item()

            # Get predictions (argmax)
            preds = torch.argmax(logits, dim=-1).cpu().numpy()
            labels = batch_labels.cpu().numpy()

            all_preds.extend(preds)
            all_labels.extend(labels)

    #calculate validation loss
    avg_val_loss = total_val_loss / len(dataloader)

    # convert IDs back to Tags (removing -100)
    decoded_preds = [
        [label_list[p] for (p, l) in zip(pred, label) if l != -100]
        for pred, label in zip(all_preds, all_labels)
    ]
    decoded_labels = [
        [label_list[l] for (p, l) in zip(pred, label) if l != -100]
        for pred, label in zip(all_preds, all_labels)
    ]

    # compute metrics using seqeval (Strict Entity-Level scoring)
    results = seqeval.compute(predictions=decoded_preds, references=decoded_labels)

    return {
        "val_loss": avg_val_loss,
        "accuracy": results["overall_accuracy"],
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"]
    }
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %% [markdown]
# Function for training loop with evaluation metric after each epoch

# %%
def train_eval_lstm(model, optimizer, n_epoches = 5, early_stopping=False):
  print("Starting Bi-LSTM for NER training...")

  history = {
      "train_loss": [],
      "val_loss": [],
      "accuracy": [],
      "precision": [],
      "recall": [],
      "f1": []
  }

  patience = 3
  patience_counter = 0
  best_val_loss = np.inf #initializing to infinite so that the first loss is always an improvement

  for epoch in range(n_epoches):
      # train
      model.train()
      total_loss = 0

      for batch_ids, batch_labels in train_loader:
          optimizer.zero_grad()
          loss, logits = model(batch_ids, batch_labels)
          loss.backward()
          optimizer.step()
          total_loss += loss.item()

      avg_train_loss = total_loss / len(train_loader)

      # validation on test set to calculate metrics
      metrics = evaluate_epoch(model, validation_loader, label_list)

      # tracking history of metrics
      history["train_loss"].append(avg_train_loss)
      history["val_loss"].append(metrics["val_loss"])
      history["accuracy"].append(metrics["accuracy"])
      history["precision"].append(metrics["precision"])
      history["recall"].append(metrics["recall"])
      history["f1"].append(metrics["f1"])

      print(f"Epoch {epoch+1}/{n_epoches} | "
            f"Train Loss: {avg_train_loss:.4f} | "
            f"Val Loss: {metrics['val_loss']:.4f} | "
            f"Val Recall: {metrics['recall']:.4f} | "
            f"Val Precision: {metrics['precision']:.4f} |"
            f"Val F1: {metrics['f1']:.4f} |"
            f"Val Accuracy: {metrics['accuracy']:.4f}")

      #early stopping
      if early_stopping == True:
        epoch_val_loss = metrics["val_loss"]
        if epoch_val_loss < best_val_loss:
            # if validation loss is improving/decreasing
            print(f"Validation Loss improved from {best_val_loss:.4f} to {epoch_val_loss:.4f}.")
            best_val_loss = epoch_val_loss
            patience_counter = 0  # reset the counter

        else:
            # validation loss increasing
            patience_counter += 1
            print(f"No improvement in validation loss. Patience: {patience_counter}")

            if patience_counter >= patience:
                print("Early Stopping triggered! Training stopped.")
                break # early stop


  print("Training complete!")
  return history

# %% [markdown]
# function for plotting the evaluation metrics vs epoch

# %%
def plot_training_metrics(history):
    epochs_range = range(1, len(history['train_loss']) + 1)

    plt.figure(figsize=(18, 6))

    # training vs validation loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, history['train_loss'], 'r-o', label='Training Loss')
    plt.plot(epochs_range, history['val_loss'], 'b-o', label='Validation Loss')
    plt.title('Training Loss vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # R vs P vs A vs F1
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, history['recall'], 'b-o', label='Val Recall')
    plt.plot(epochs_range, history['f1'], 'g-o', label='Val F1 Score')
    plt.plot(epochs_range, history['accuracy'], 'k-x', label='Accuracy', linestyle='--')
    plt.plot(epochs_range, history['precision'], 'r-o', label='Precision')
    plt.title('Validation R vs P vs A vs F1')
    plt.xlabel('Epochs')
    plt.ylabel('Score')
    plt.ylim(0, 1.0) # y-axis to 0-100%
    plt.legend(loc='lower right')
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Training & Evaluation LSTM model v1

# %%
# vocab_size is 30522 for DistilBERT
# num_labels is len(label_list)
lstm_nre_v1 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=256).to(device)
optimizer_v1 = torch.optim.Adam(lstm_nre_v1.parameters(), lr=1e-4)

# %%
history_v1 = train_eval_lstm(lstm_nre_v1, optimizer_v1, n_epoches = 10)
# Out:
# Starting Bi-LSTM for NER training...
# /usr/local/lib/python3.12/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.12/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/10 | Train Loss: 1.8374 | Val Loss: 0.6535 | Val Recall: 0.0000 | Val Precision: 0.0000 |Val F1: 0.0000 |Val Accuracy: 0.8740
# Epoch 2/10 | Train Loss: 0.6269 | Val Loss: 0.5447 | Val Recall: 0.0000 | Val Precision: 0.0000 |Val F1: 0.0000 |Val Accuracy: 0.8740
# Epoch 3/10 | Train Loss: 0.5351 | Val Loss: 0.4605 | Val Recall: 0.0066 | Val Precision: 0.0899 |Val F1: 0.0122 |Val Accuracy: 0.8789
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1152621742.py in <cell line: 0>()
# ----> 1 history_v1 = train_eval_lstm(lstm_nre_v1, optimizer_v1, n_epoches = 10)
#
# /tmp/ipython-input-1340111999.py in train_eval_lstm(model, optimizer, n_epoches, early_stopping)
#      24           loss, logits = model(batch_ids, batch_labels)
#      25           loss.backward()
# ---> 26           optimizer.step()
#      27           total_loss += loss.item()
#      28
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     515                             )
#     516
# --> 517                 out = func(*args, **kwargs)
#     518                 self._optimizer_step_code()
#     519
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in _use_grad(*args, **kwargs)
#      80             torch.set_grad_enabled(self.defaults["differentiable"])
#      81             torch._dynamo.graph_break()
# ---> 82             ret = func(*args, **kwargs)
#      83         finally:
#      84             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in step(self, closure)
#     245             )
#     246
# --> 247             adam(
#     248                 params_with_grad,
#     249                 grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in maybe_fallback(*args, **kwargs)
#     148                 return disabled_func(*args, **kwargs)
#     149             else:
# --> 150                 return func(*args, **kwargs)
#     151
#     152         return maybe_fallback
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     951         func = _single_tensor_adam
#     952
# --> 953     func(
#     954         params,
#     955         grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     533                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     534             else:
# --> 535                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     536
#     537             param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#
# KeyboardInterrupt:

# %%
# plot evaluation metrics
plot_training_metrics(history_v1)

# %% [markdown]
# Observation: Model is actually learning and the overfitting at epoch 10 is almost negligible. But, a high accuracy of 94.82% with a low recall and precision of 53.58% shows that the model has learnt that predicting non-entity (label 'O') most of the times is a safe bet.

# %% [markdown]
# Implementing weighted loss strategy to tell the model that missing an entity is worst than getting a non-entity wrong.

# %% [markdown]
# To calculate weights, if the tag occurs more number of times like the non-entity tag 'O', we need to give it lower weight. Using sklearn class_weight utility to compute this.

# %%
from sklearn.utils.class_weight import compute_class_weight
#list of all tags in training set
all_classes = [label
              for row in train_distilbert['labels']
                for label in row
                  if label != -100
]
unique_classes = np.unique(all_classes)

#balanced mode adjusts the weights inversly proportional to the frequencies of the classes
weights = compute_class_weight(class_weight='balanced', classes = unique_classes, y = all_classes)

#convert class weights to pytorch tensor
class_weights = torch.tensor(weights, dtype=torch.float).to(device)

print("Calculated Class Weights:")
for i, weight in enumerate(class_weights):
    # getting label names from id2label
    label_name = id2label[i] if 'id2label' in locals() else str(i)
    print(f"{label_name}: {weight:.4f}")

# %%
#trying similar architecture with weighted loss approach
lstm_nre_v2 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=256, weight_tensor=class_weights).to(device)
optimizer_v2 = torch.optim.Adam(lstm_nre_v2.parameters(), lr=1e-4)

# %% [markdown]
# Will the model learn more if I increase the number of epoches?

# %%
history_v2 = train_eval_lstm(lstm_nre_v2, optimizer_v2, n_epoches = 15)

# %%
# plot evaluation metrics
plot_training_metrics(history_v2)

# %% [markdown]
# Observed that the model starts to overfit at epoch 5. The recall at epoch 14 has improved to 60.20% the precision has drastically dropped to 13.49%, showing that only 13.49% of the redacted words are actually sensetive! The accuracy has also dropped to 64.35%. The fact that the difference between the recall and accuracy has dropped is good.

# %% [markdown]
# What effect might it have if the number of nodes in the hidden layer of the network is increased while sticking to weighted loss strategy?

# %%
#increasing dimension of hidden layer without using weighted loss
lstm_nre_v3 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=288, weight_tensor=class_weights).to(device)
optimizer_v3 = torch.optim.Adam(lstm_nre_v3.parameters(), lr=1e-4)

# %%
history_v3 = train_eval_lstm(lstm_nre_v3, optimizer_v3, n_epoches = 13)

# %%
# plot evaluation metrics
plot_training_metrics(history_v3)

# %% [markdown]
# Observation: The model started to overfit at epoch 4. It kept learning however, the overfittin kept increasing. The best recall of 54.17% was achieved at epoch 12 which is less than the previous. Also, precision dropped to 12.85%.
#
# Trying to decrease the number of nodes in the hidden layer.

# %%
#decreasing dimension of hidden layer without using weighted loss
lstm_nre_v4 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=192, weight_tensor=class_weights).to(device)
optimizer_v4 = torch.optim.Adam(lstm_nre_v4.parameters(), lr=1e-4)

# %%
history_v4 = train_eval_lstm(lstm_nre_v4, optimizer_v4, n_epoches = 10)

# %%
# plot evaluation metrics
plot_training_metrics(history_v4)

# %% [markdown]
# Observation: The best recall for this strategy is still 53.30% with precision of 10.11%. Going back to v2 and trying to recude overfitting by adding dropout.

# %%
#trying similar architecture with weighted loss approach
lstm_nre_v5 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=256, weight_tensor=class_weights, dropout_rate=0.2).to(device)
optimizer_v5 = torch.optim.Adam(lstm_nre_v5.parameters(), lr=1e-4)

# %%
history_v5 = train_eval_lstm(lstm_nre_v5, optimizer_v5, n_epoches = 15)

# %%
# plot evaluation metrics
plot_training_metrics(history_v5)

# %% [markdown]
# Observation: This strategy has shown increased overfitting but the Recall has increased to 62.70% and the precision to 15.11%
#
# Trying an approach where increasing the number of nodes in the hidden layer without the weighted loss or dropout strategy.

# %%
#increasing dimension of hidden layer more without using weighted loss
lstm_nre_v6 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=480).to(device)
optimizer_v6 = torch.optim.Adam(lstm_nre_v6.parameters(), lr=1e-4)

# %%
history_v6 = train_eval_lstm(lstm_nre_v6, optimizer_v6, n_epoches = 30)

# %%
# plot evaluation metrics
plot_training_metrics(history_v6)

# %% [markdown]
# Observation: After epoch 10 the model is learning slowly but could reach 71.75% recall and 77.77% precision at epoch 20 however, the model is not learning much after that. Some amount of overfitting is seen after epoch 10.
#
# Adding dropout layers to reduce overfitting.

# %%
#adding dropout layer to reduce overfitting and reducing epoches
lstm_nre_v7 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=480, dropout_rate=0.2).to(device)
optimizer_v7 = torch.optim.Adam(lstm_nre_v7.parameters(), lr=1e-4)

# %%
history_v7 = train_eval_lstm(lstm_nre_v7, optimizer_v7, n_epoches = 21)

# %%
# plot evaluation metrics
plot_training_metrics(history_v7)

# %% [markdown]
# Observation: There is not much change in the overfitting but the max recall achieved at epoch 20 is 66.68% which is lower than the previous model.
#
# Implementing early stopping on v6 for final training run.

# %%
#increasing dimension of hidden layer more without using weighted loss
lstm_nre_v8 = bilstm_nre(30522, len(label_list), embed_dim=128, hidden_dim=480).to(device)
optimizer_v8 = torch.optim.Adam(lstm_nre_v8.parameters(), lr=1e-4)

# %%
history_v8 = train_eval_lstm(lstm_nre_v8, optimizer_v8, n_epoches = 30, early_stopping=True)

# %%
# plot evaluation metrics
plot_training_metrics(history_v8)

# %% [markdown]
# Observation: The validation loss stopped improving for 2 epoches twice but then improved again, so no early stopping was triggered. The epoch 29 gave us the best model with:
# Train Loss: 0.1085
# Val Loss: 0.1641
# Val Recall: 72.50%
# Val Precision: 79.19%
# Val F1: 75.70%
# Val Accuracy: 96.01%

# %% [markdown]
# Evaluating this best bi-lstm-model on test set.

# %%
lstm_ner_metrics = evaluate_epoch(lstm_nre_v8, test_loader, label_list)

# %%
print(f"Testing Loss: {lstm_ner_metrics['val_loss']}")
print(f"Accuracy: {(lstm_ner_metrics['accuracy'] * 100):.4f}% - tokens were correctly classified")
print(f"Precision: {(lstm_ner_metrics['precision'] * 100):.4f}% - were correctly redacted out of all redacted tokens")
print(f"Recall: {(lstm_ner_metrics['recall'] * 100):.4f}% - tokens were correctly identified for redaction")
print(f"F1: {(lstm_ner_metrics['f1'] * 100):.4f}% - is the readability score")

# %% [markdown]
# ### 5. LegalBERT Finetuning (Liza)

# %%
# 5. Legal-BERT Finetuning (Liza)

# !pip install seqeval evaluate transformers datasets

import numpy as np
import pandas as pd
import evaluate
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification

# going with legal-bert since it handles domain specific terms better than vanilla bert
model_checkpoint = "nlpaueb/legal-bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
metric = evaluate.load("seqeval")

# standard bio tags
label_list = ["O", "B-PER", "I-PER", "B-LOC", "I-LOC", "B-ORG", "I-ORG"]
label2id = {label: i for i, label in enumerate(label_list)}
id2label = {i: label for i, label in enumerate(label_list)}

# just mapping raw types to our simplified schema
type_mapper = {"PERSON": "PER", "ORGANIZATION": "ORG", "LOCATION": "LOC", "ORG": "ORG", "LOC": "LOC", "PER": "PER"}

def tokenize_and_align_labels(examples):
    # the main tricky part: raw data gives us char indices (start=10, end=15),
    # but bert sees tokens. simply splitting by space fails on punctuation (e.g. "Ivanov,").
    # so i'm using offset_mapping from the tokenizer to align labels correctly.

    tokenized_inputs = tokenizer(
        examples["text"], truncation=True, max_length=512,
        return_offsets_mapping=True, padding="max_length"
    )
    labels = []

    for i, doc_offsets in enumerate(tokenized_inputs["offset_mapping"]):
        doc_mentions = examples["entity_mentions"][i] if examples["entity_mentions"][i] is not None else []

        doc_labels = [0] * len(doc_offsets)
        for idx, (start, end) in enumerate(doc_offsets):
            if start == end:
                doc_labels[idx] = -100 # ignore special tokens
                continue

            for mention in doc_mentions:
                if start >= mention['start_offset'] and end <= mention['end_offset']:
                    raw_type = mention['entity_type']
                    short_type = type_mapper.get(raw_type, "ORG")

                    # logic for B- vs I- tags
                    prefix = "B-" if start == mention['start_offset'] else "I-"
                    label_name = f"{prefix}{short_type}"
                    doc_labels[idx] = label2id.get(label_name, 0)
                    break
        labels.append(doc_labels)

    tokenized_inputs["labels"] = labels
    tokenized_inputs.pop("offset_mapping") # we don't need this for training
    return tokenized_inputs

# using the shared dataframes (df_train etc) loaded at the top of the notebook
# converting them to hf dataset format and applying the alignment fix
print("prepping data for legal-bert...")

raw_datasets = DatasetDict({
    "train": Dataset.from_pandas(df_train),
    "validation": Dataset.from_pandas(df_validation),
    "test": Dataset.from_pandas(df_test)
})

tokenized_datasets = raw_datasets.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=raw_datasets["train"].column_names
)
print("done. tokens aligned.")
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from seqeval) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.12/dist-packages (from seqeval) (1.6.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from evaluate) (4.67.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from evaluate) (1.3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from evaluate) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (0.28.1)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->evaluate) (2026.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.7.0->evaluate) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.7 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=9929a98a6ed0db6b9ca2965031914d9d0cf204e49191f3d5eff5f78a00ca292b
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# Installing collected packages: seqeval, evaluate
# Successfully installed evaluate-0.4.6 seqeval-1.2.2
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# prepping data for legal-bert...
# Map:   0%|          | 0/1112 [00:00<?, ? examples/s]
# Map:   0%|          | 0/541 [00:00<?, ? examples/s]
# Map:   0%|          | 0/555 [00:00<?, ? examples/s]
# done. tokens aligned.

# %%
# 1. Сначала определяем метрики и токенайзер, чтобы Python их видел
import numpy as np
import pandas as pd
import evaluate
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification

# Определяем токенайзер ПРЯМО ЗДЕСЬ, чтобы не было ошибки NameError
model_checkpoint = "nlpaueb/legal-bert-base-uncased"
tokenizer_legal = AutoTokenizer.from_pretrained(model_checkpoint)
metric = evaluate.load("seqeval")

# Список меток (нужен для метрик)
label_list = ["O", "B-PER", "I-PER", "B-LOC", "I-LOC", "B-ORG", "I-ORG"]
label2id = {label: i for i, label in enumerate(label_list)}
id2label = {i: label for i, label in enumerate(label_list)}

def evaluate_model_performance(trainer, eval_dataset, model_name="MyModel"):
    print(f"--- Evaluating {model_name} ---")
    predictions, labels, _ = trainer.predict(eval_dataset)
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = metric.compute(predictions=true_predictions, references=true_labels)

    return {
        "Model": model_name,
        "F1 Score": results['overall_f1'],
        "Recall": results['overall_recall'],
        "Precision": results['overall_precision'],
        "Accuracy": results['overall_accuracy']
    }

# 2. Инициализируем модель
model = AutoModelForTokenClassification.from_pretrained(
    model_checkpoint,
    num_labels=len(label_list),
    id2label=id2label,
    label2id=label2id
)

# 3. Настройки обучения
args = TrainingArguments(
    "legal-bert-ner",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    save_strategy="no",
    logging_steps=50
)

# 4. Создаем Trainer (и используем tokenizer_legal, который объявили выше)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=DataCollatorForTokenClassification(tokenizer_legal) # <--- ТЕПЕРЬ ОН ТУТ ЕСТЬ
)

# --- БЕНЧМАРК (ДО) ---
print("Running benchmark on pre-trained model (before fine-tuning)...")
metrics_pre = evaluate_model_performance(
    trainer,
    tokenized_datasets["test"],
    model_name="Legal-BERT (Pre-trained / Zero-shot)"
)
print(">>> Pre-trained F1 score:", metrics_pre['F1 Score'])

# --- ОБУЧЕНИЕ ---
print("Starting training...")
trainer.train()

# --- ПРОВЕРКА (ПОСЛЕ) ---
print("Evaluating fine-tuned model...")
metrics_finetuned = evaluate_model_performance(
    trainer,
    tokenized_datasets["test"],
    model_name="Legal-BERT (Fine-tuned)"
)

# --- ТАБЛИЦА ---
print("\n Proof that fine-tuning worked:")
display(pd.DataFrame([metrics_pre, metrics_finetuned]).round(4))
# Out:
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: nlpaueb/legal-bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# bert.pooler.dense.weight                   | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# bert.pooler.dense.bias                     | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Running benchmark on pre-trained model (before fine-tuning)...
# --- Evaluating Legal-BERT (Pre-trained / Zero-shot) ---
# >>> Pre-trained F1 score: 0.0020237290090543525
# Starting training...
#     <div>
#
#       <progress value='210' max='210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [210/210 06:11, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Model Preparation Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.557582</td>
#       <td>0.134368</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.138445</td>
#       <td>0.105691</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.093444</td>
#       <td>0.103792</td>
#       <td>0.004000</td>
#     </tr>
#   </tbody>
# </table><p>
# Evaluating fine-tuned model...
# --- Evaluating Legal-BERT (Fine-tuned) ---
#  Proof that fine-tuning worked:
#                                   Model  F1 Score  Recall  Precision  Accuracy
# 0  Legal-BERT (Pre-trained / Zero-shot)    0.0020  0.0116     0.0011    0.0496
# 1               Legal-BERT (Fine-tuned)    0.8082  0.8292     0.7881    0.9633

# %%
# --- STEP 6: FINAL EVALUATION & VISUALIZATION ---

# 1. Считаем финальные метрики (на всякий случай, чтобы точно были)
metrics_legal = evaluate_model_performance(trainer, tokenized_datasets["test"], model_name="Legal-BERT (Liza Final)")

print("\n🏆 FINAL RESULTS TABLE:")
display(pd.DataFrame([metrics_legal]).round(4))

# 2. Рисуем ГРАФИК и сохраняем его (для отчета)
import matplotlib.pyplot as plt
import json
import os

# Создаем папку, если нет
output_dir = "./legal_bert_output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Сохраняем саму модель (ПРЕДУПРЕЖДЕНИЕ: весит 400мб, не пушь на гитхаб!)
print(f"Saving model artifacts to {output_dir}...")
trainer.save_model(output_dir)
tokenizer.save_pretrained(output_dir)

# Сохраняем историю обучения (циферки)
history = trainer.state.log_history
history_path = f"{output_dir}/training_history.json"
with open(history_path, "w") as f:
    json.dump(history, f)

# 3. 🔥 РИСУЕМ ГРАФИК (Loss Curve)
train_loss = [x['loss'] for x in history if 'loss' in x]
steps = [x['step'] for x in history if 'loss' in x]

if train_loss:
    plt.figure(figsize=(10, 6))
    # Рисуем линию обучения (синяя)
    plt.plot(steps, train_loss, label="Training Loss", color="blue")

    # Рисуем линию валидации (красная) - если она есть
    val_loss = [x['eval_loss'] for x in history if 'eval_loss' in x]
    val_steps = [x['step'] for x in history if 'eval_loss' in x]
    if val_loss:
        plt.plot(val_steps, val_loss, label="Validation Loss", color="red")

    plt.xlabel("Steps")
    plt.ylabel("Loss")
    plt.title("Training Progress (Legal-BERT)")
    plt.legend()
    plt.grid(True)

    # Сохраняем картинку в файл
    graph_path = f"{output_dir}/training_graph.png"
    plt.savefig(graph_path)
    print(f"\n✅ Graph saved to: {graph_path}")
    print("👉 Download this image for your presentation!")
    plt.show()
else:
    print("Not enough history to plot graph yet.")
# Out:
# --- Evaluating Legal-BERT (Liza Final) ---
# 🏆 FINAL RESULTS TABLE:
#                      Model  F1 Score  Recall  Precision  Accuracy
# 0  Legal-BERT (Liza Final)    0.8082  0.8292     0.7881    0.9633
# Saving model artifacts to ./legal_bert_output...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Graph saved to: ./legal_bert_output/training_graph.png
# 👉 Download this image for your presentation!

# %% [markdown]
# ### 7. DistilBERT Finetuning (Mit)

# %% [markdown]
# Using tokenized datasets: train_distilbert, test_distilbert, validation_distilbert

# %% [markdown]
# ### 8. Pre-trained DistilBERT - Benchmarking (Sayed)

# %% [markdown]
# Using tokenized datasets: train_distilbert, test_distilbert, validation_distilbert

# %% [markdown]
# ### 9. RoBERTa, BERT-NER, ALBERT
# These are some more models that can be used. Feel free to pick any and start working
